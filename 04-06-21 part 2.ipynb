# %%
import matplotlib as mpl

# %% [markdown]
# matplotlib
# --------------
# - matplolib is one of the libraray in python for constructing 2d plotting visualisation:
# - is used to create high quality graphs ,plots ,charts,figures etc
#
# pyplot
# ---------
# - pyplot is one of the popular module in matplotlib library and it contains colection of functions

# %%
import matplotlib.pyplot as plt

# %%
x = [10,12,13,15]
y = [5,6,7,8]
plt.plot(x,y)
plt.show()

# %%
x = [10,12,14,16]
y = [5,6,7,8]
plt.plot(x,y,label = "Line")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.tittle("Line plot")
plt.legend(loc="upper left")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-71c5a6bbfb93> in <module>
#       4 plt.xlabel("x-axis")
#       5 plt.ylabel("y-axis")
# ----> 6 plt.tittle("Line plot")
#       7 plt.legend(loc="upper left")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
import numpy as np
x = np.linspace(0,5,20)
x
# Out:
# array([0.        , 0.26315789, 0.52631579, 0.78947368, 1.05263158,
#        1.31578947, 1.57894737, 1.84210526, 2.10526316, 2.36842105,
#        2.63157895, 2.89473684, 3.15789474, 3.42105263, 3.68421053,
#        3.94736842, 4.21052632, 4.47368421, 4.73684211, 5.        ])

# %%
plt.plot(x,x**2,color = "red",label = "squares")
plt.plot(x,x**3,color = "green",label = "cubes")
plt.plot(x,x**4,color = "yellow",label = "four")
plt.legend()

# %%
plt.plot(x,x+10,color = 'g',linestyle = '--')
plt.plot(x,x+20,color = 'm',linestyle = '--')

# %%
year = ['2019 Dec','2020 jan','2020 March','2020 July']
goldprice = [10000,20000,30000,40000]
plt.bar(year,goldprice)

# %%
x = np.arange(5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.barh(x,[90,82,55,67,77],color = 'r')
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.random.randint(1000,1500,30)
y = np.random.randint(500,1000,30)
plt.scatter(x,y)

# %%
games = ["football","kabbadi","cricket","chess"]
score = [80,92,75,50]
plt.pie(score,labels = games,)
# Out:
# ([<matplotlib.patches.Wedge at 0x2baf96d4400>,
# ...
#  [Text(0.7290998777335884, 0.823658526507719, 'football'),
#   Text(-0.9777189863700384, 0.5040491877699484, 'kabbadi'),
#   Text(-0.3043195026392061, -1.057066525963918, 'cricket'),
#   Text(0.9497056885106658, -0.5550307245643996, 'chess')])

# %%
games = ["football","kabbadi","cricket","chess"]
score = [80,92,75,50]
plt.pie(score,labels = games,explode =(0,0.2,0,0),startangle = 90,colors = ["c","g","m","pink"],shadow = True)
plt.show()

# %%
games = ["football","kabbadi","cricket","chess"]
score = [80,92,75,50]
plt.pie(score,labels = games,explode =(0,0.2,0,0),startangle = 90,colors = ["c","g","m","pink"],shadow = True)
plt.show()
plt.savefig('piechart.png')

# %%
h = [0,0.5,0.6,1.5,1.6,3.6,3.7,3.8,5.5,5.1,5.2]
bins = 4
plt.hist(h,bins,rwidth = 0.4)
# Out:
# (array([3., 2., 3., 3.]),
#  array([0.   , 1.375, 2.75 , 4.125, 5.5  ]),
#  <BarContainer object of 4 artists>)

# %%
days = [1,2,3,4,5]
age = [40,15,78,45,25]
weight = [15,30,70,48,60]
plt.stackplot(days,age,weight,colors = ['c','g'])
plt.show()
